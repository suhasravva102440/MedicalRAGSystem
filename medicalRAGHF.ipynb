# %%
! pip install langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain-community)
#   Using cached langchain_core-1.2.14-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Using cached langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Using cached sqlalchemy-2.0.46-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Using cached aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-community)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.7.6-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.7.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.1->langchain-community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.0.1->langchain-community)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Using cached orjson-3.11.7-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Using cached xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Using cached zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.1.4)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Using cached greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-1.2.14-py3-none-any.whl (501 kB)
# Downloading langsmith-0.7.6-py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.5 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/325.5 kB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 122.9/325.5 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  317.4/325.5 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 325.5/325.5 kB 2.2 MB/s eta 0:00:00
# Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl (12.3 MB)
# Using cached pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Using cached sqlalchemy-2.0.46-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached greenlet-3.3.2-cp312-cp312-win_amd64.whl (231 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.1-cp312-cp312-win_amd64.whl (46 kB)
# Using cached orjson-3.11.7-cp312-cp312-win_amd64.whl (125 kB)
# Using cached propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.1 kB ? eta -:--:--
#    ---------------------------------------- 187.1/187.1 kB 5.7 MB/s eta 0:00:00
# Using cached xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Using cached yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Using cached zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tenacity, python-dotenv, pydantic-core, propcache, orjson, numpy, mypy-extensions, multidict, marshmallow, jsonpatch, httpx-sse, greenlet, frozenlist, annotated-types, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests-toolbelt, pydantic, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-classic, langchain-community
# Successfully installed SQLAlchemy-2.0.46 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-types-0.7.0 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.3.2 httpx-sse-0.4.3 jsonpatch-1.33 langchain-classic-1.0.1 langchain-community-0.4.1 langchain-core-1.2.14 langchain-text-splitters-1.1.1 langsmith-0.7.6 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.4.2 orjson-3.11.7 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.13.1 python-dotenv-1.2.1 requests-toolbelt-1.0.0 tenacity-9.1.4 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.6.0 yarl-1.22.0 zstandard-0.25.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from tqdm) (0.4.6)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.3
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the documents

from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import TextLoader

loader = DirectoryLoader('medicaldata/notes', glob="*.txt", show_progress=True, loader_cls=TextLoader)

kb_docs = loader.load()


# Chunk the loaded documents

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)

chunks = text_splitter.split_documents(kb_docs)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 30.44it/s]

# %%
! pip install sentence-transformers
! pip install langchain-huggingface
! pip install langchain-chroma
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.2.3-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-5.2.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub>=0.20.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from sentence-transformers) (0.36.2)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from sentence-transformers) (2.4.2)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: filelock in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: packaging>=20.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: colorama in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Collecting regex!=2019.12.17 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached regex-2026.2.19-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer-slim (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Collecting shellingham (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting joblib>=1.3.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Collecting typer>=0.24.0 (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting click>=8.2.1 (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting rich>=12.3.0 (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.6.3)
# Using cached sentence_transformers-5.2.3-py3-none-any.whl (494 kB)
# Using cached torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
# Using cached transformers-5.2.0-py3-none-any.whl (10.4 MB)
# Using cached huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
# Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached regex-2026.2.19-cp312-cp312-win_amd64.whl (277 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, shellingham, scipy, safetensors, regex, networkx, mdurl, joblib, hf-xet, click, annotated-doc, torch, scikit-learn, markdown-it-py, rich, typer, typer-slim, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
# Successfully installed annotated-doc-0.0.4 click-8.3.1 hf-xet-1.2.0 huggingface-hub-1.4.1 joblib-1.5.3 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 regex-2026.2.19 rich-14.3.3 safetensors-0.7.0 scikit-learn-1.8.0 scipy-1.17.1 sentence-transformers-5.2.3 shellingham-1.5.4 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.2 torch-2.10.0 transformers-5.2.0 typer-0.24.1 typer-slim-0.24.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-1.2.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting huggingface-hub<1.0.0,>=0.33.4 (from langchain-huggingface)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-huggingface) (1.2.14)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2026.2.0)
# Requirement already satisfied: packaging>=20.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: requests in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.7.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2026.1.4)
# Requirement already satisfied: colorama in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (4.12.1)
# Requirement already satisfied: httpcore==1.* in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.16.0)
# Using cached langchain_huggingface-1.2.0-py3-none-any.whl (30 kB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub, langchain-huggingface
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
# Successfully installed huggingface-hub-0.36.2 langchain-huggingface-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.2.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain-chroma
#   Using cached langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb<2.0.0,>=1.3.5 (from langchain-chroma)
#   Using cached chromadb-1.5.1-cp39-abi3-win_amd64.whl.metadata (7.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-chroma) (1.2.14)
# Requirement already satisfied: numpy>=1.26.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-chroma) (2.4.2)
# Collecting build>=1.0.3 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=1.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Collecting pybase64>=1.4.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pybase64-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached onnxruntime-1.24.2-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached grpcio-1.78.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting bcrypt>=4.0.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Collecting kubernetes>=28.1.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: anyio in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: certifi in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.32.5)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.36.2)
# Requirement already satisfied: click>=8.2.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached httptools-0.7.1-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.1)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached watchfiles-1.1.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.0)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: mdurl~=0.1 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.4.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\mltraining\hands-on-labs[ali team]\langchain_experiments\medical_langchain\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Using cached langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Using cached chromadb-1.5.1-cp39-abi3-win_amd64.whl (21.9 MB)
# Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Using cached build-1.4.0-py3-none-any.whl (24 kB)
# Using cached grpcio-1.78.1-cp312-cp312-win_amd64.whl (4.8 MB)
# Using cached kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.24.2-cp312-cp312-win_amd64.whl (12.5 MB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached pybase64-1.4.3-cp312-cp312-win_amd64.whl (35 kB)
# Using cached pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Using cached uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached httptools-0.7.1-cp312-cp312-win_amd64.whl (86 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Using cached watchfiles-1.1.1-cp312-cp312-win_amd64.whl (288 kB)
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/178.7 kB ? eta -:--:--
#    ---- ---------------------------------- 20.5/178.7 kB 162.5 kB/s eta 0:00:01
#    ------ -------------------------------- 30.7/178.7 kB 217.9 kB/s eta 0:00:01
#    --------------- ----------------------- 71.7/178.7 kB 393.8 kB/s eta 0:00:01
#    -------------------------------------  174.1/178.7 kB 807.1 kB/s eta 0:00:01
#    -------------------------------------- 178.7/178.7 kB 719.9 kB/s eta 0:00:00
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, pyproject_hooks, pybase64, protobuf, overrides, oauthlib, mmh3, importlib-resources, httptools, grpcio, distro, bcrypt, backoff, watchfiles, uvicorn, requests-oauthlib, posthog, opentelemetry-proto, onnxruntime, importlib-metadata, googleapis-common-protos, build, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, kubernetes, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
# Successfully installed backoff-2.2.1 bcrypt-5.0.0 build-1.4.0 chromadb-1.5.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.12.19 googleapis-common-protos-1.72.0 grpcio-1.78.1 httptools-0.7.1 importlib-metadata-8.7.1 importlib-resources-6.5.2 kubernetes-35.0.0 langchain-chroma-1.1.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.24.2 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 overrides-7.7.0 posthog-5.4.0 protobuf-6.33.5 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 uvicorn-0.41.0 watchfiles-1.1.1 websockets-16.0 zipp-3.23.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_chroma import Chroma

from langchain_huggingface import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": False}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Initialize a ChromaDB Connection
from langchain_chroma import Chroma

# Initialize the database connection
# If database exist, it will connect with the collection_name and persist_directory
# Otherwise a new collection will be created
db = Chroma(collection_name="vector_database", 
            embedding_function=hf, 
            persist_directory="./chroma_db_")

db.add_documents(documents=chunks)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['a6079290-eda6-4019-a560-0bd4301d2b16',
#  '53a0ae42-3c4c-4b3a-9d2d-1fc3add3cf34',
#  '4273e8a0-a60a-48cf-bb64-d363671914da',
#  '3a02d151-d872-4257-acf3-53bcbe1fefcd',
#  '2b7c5f22-71be-419a-9ec2-81312d4aea05',
#  '50cedf4a-cee5-4b60-9eae-638ad5539da1',
#  'ee4752ee-528c-4a0e-90d9-9159ba9957f8',
#  '1976556f-66ff-4c80-bf00-1f99f9bbd075',
#  'f5f62b84-dfae-4ee0-a02a-cbe241032314',
#  '16e4bb9c-d7a9-40c9-8062-6ea05d1034e8',
#  'df57c04b-0410-47f7-afbe-57011c2b4fbb',
#  'cba9727f-cba3-4beb-b89d-af0d36eda009',
#  '2f20a917-1c1d-4ab0-a58e-cc05ca390b10',
#  '2a0465af-65c2-4e92-967b-553c4f565015',
#  'fb69f728-89d0-4fe4-9607-63458eb4fd07',
#  'ba157155-d13b-4159-963d-e84fc544031d',
#  'b5d8769d-29f7-4f2a-bef6-e100fb49ce15',
#  'b8b3579d-0724-4334-ae22-35176425b402',
#  'c54daab9-0054-4614-b4b3-d1af91b51be1',
#  '4ba74818-2782-43ea-b55c-068b6538c000',
#  '56ec8163-8b68-4ee6-a42d-3d7059861434',
#  '1b1bdaee-5ed0-4d03-a8b8-c72417733016',
#  '0e3ca080-a258-4bfa-9776-2713b2e57c69',
#  '8f9aa1b9-aa11-46cf-a065-e0820fc8093f',
#  'dc90f9b3-ee35-4fbb-813f-89b801da61c5',
#  'd1f2ac45-349e-454f-b945-1c6f37e0ec4b',
#  '722c6276-abc2-46a7-bc3c-ebb9164262ff',
#  'faccc74b-c5df-4825-b9d6-fec9e24fe798',
#  'ca93d4d0-4aeb-4ece-ad8e-0cbb47bdab06',
#  '14af86e0-3195-4973-b26f-e8cd005cccc0',
#  '8f34ec20-2c9d-4a5a-91b9-5f697a03c935',
#  '50b7b7e8-fbeb-4e40-a22c-9aaac50e1a77',
#  '37e4b5f2-f83a-4327-8c59-5cb93738b538',
#  'eccab2b4-8143-46d6-9d76-d67869fa0b4c',
#  'a16ebfff-9b1a-46cb-86a1-3b95619025cb',
#  'f3186880-2140-4de6-ab50-499a8673f240',
#  'c529c985-84a6-40de-a5dc-ab6cea528ac6',
#  '7e1d2de4-a56f-4871-838c-f67d385ffa8a',
#  '558bc66f-54ea-4a2f-a067-4b42dcfb1590',
#  '7d0464ed-1c88-4858-b906-16e1825e7022',
#  'c6a9f342-fe67-497e-af7e-aad2cb811a2c',
#  '90cb2ad2-d46f-47b8-9c8f-b82200bfffa6',
#  '494606d8-656d-4cf6-afab-80a2e6a5488b',
#  'a4c63f07-1931-4ba8-aac5-5a67a873e4dd',
#  '63b78d2c-fe7d-4921-8174-9f366573f52d',
#  '9313e517-28f4-4ad4-8c3f-0a506e98189c',
#  '1a7868df-ac99-419a-bafb-d36cf14c7dfa',
#  '121ebf63-941c-4768-9d6e-49a9741b5861',
#  'c756bf90-2605-4944-ac49-35a79e36fdbb',
#  'c65699a4-6e46-4c9f-8dd7-28f6d8afd0ee',
#  '2fc25119-9ff4-4079-8149-ee5e2666e46e',
#  'a0c26a2f-9611-4497-b993-15fe1de46975',
#  '97b38d90-d0bd-496b-a925-64eba8c029bf',
#  '9469aa49-aa45-4fa4-8cc8-2678da74324a',
#  '5c7122ab-065d-4690-a7ac-3f3076845065',
#  '58b3f8c1-241a-4474-a66a-0d021f15f3bd',
#  'e308800c-59d5-47eb-acc7-73a21817bcc6',
#  'a4b39c46-9014-4e43-a56e-9bd119dcb2d6',
#  '4226f01e-c15d-4b4b-9a14-f37ab77b9ae9',
#  'a8bb6339-82f9-4765-bc8e-befba75220d1',
#  'bebd5aad-ad18-4985-b3f2-af69c732d536',
#  '799982b8-7e52-441e-96c3-a75a260980ca',
#  '62f2dfcb-e788-4388-b3c5-274d6f19af1b',
#  'a912dfb9-92d7-42d5-b54e-28560fe89d34',
#  '9fd5f2a4-4920-4a44-ad17-a4dd284a04b4',
#  'f512a064-a5d7-4bb2-a3d4-7aa60e1a0541',
#  'd1c659e8-1bd6-4f06-a3ec-8c7e0f592a72',
#  '014827c1-f8e3-4940-a3fe-16569e046170',
#  'a6a1d904-cea9-42d8-bb74-131f54c9cad5',
#  '225945a5-7665-424b-85fb-20edf9570bc7',
#  '09ecf5a8-58fa-42b0-9445-81c3f55cec47',
#  '38c1bcd6-c7cb-4b4a-8eb4-a695d968ec79',
#  'c3bd8070-4827-4d07-8d5c-cd97837ad0b0',
#  '7602b4de-39c2-47f6-bfcd-abdbe96f5b30',
#  'd12eac34-2486-4ac0-99c4-57c32806f9d1',
#  'a5b088a5-64b6-43c3-a28f-b70acd12b3e4',
#  'd94b6a0a-33e2-43bd-a8a5-77d1623d0c8c',
#  '94fb3c9e-172c-4416-896b-7ff3ee2c35df',
#  '5bbe482a-459b-47df-8b40-f8fba40a9c75',
#  '2daffdf6-3c99-44dd-91aa-dbfe494ffa41',
#  '5fba4bab-ecda-426e-b466-32ba3807fc91',
#  '124a0d91-06e7-4cdf-96b6-52cdbe7f3f1c',
#  '8912ca13-ba8d-4cd4-9e43-131afe643008',
#  '7f584837-93cf-4d57-9ca4-f356869f4a22',
#  '1772d160-d94f-48fe-b28c-0a3a2858370e',
#  'd3aaccd7-21dc-4dec-943f-71a7063dbda3',
#  '60828e4a-bbbb-425c-8e43-30167327da5c',
#  '7ab545c3-daad-4241-9182-542db674226f',
#  'cbb6c42d-8ba3-4b50-bd76-50215c088b5d',
#  'f5a981e2-abde-4b1e-ad03-ad073e9b19cb',
#  '2fbdb02f-3509-4634-9215-765ec8a6684a',
#  '395101e2-de98-4be2-9244-4ea1bf9f9d2d',
#  '67753df7-c6c8-4cbf-9d7f-e46005a7ede7',
#  '190c7ea6-7de3-4733-be60-8e7626375bb7',
#  '20717796-e67c-4413-95e3-5180c8658231',
#  '71ca01ae-5fd7-47bc-afd4-680f920dd584',
#  '4bcc5d1d-3a56-4d05-9128-9d8bf28e1789',
#  '8ffef8ed-eb9b-40fe-aa67-d4e901cc342e',
#  'f14b5ffe-b487-4a1e-adfb-02cdfab3ee96',
#  'b759a901-53ea-4a97-a3d5-025a54eb2d2b',
#  '3bf285fa-453e-4899-b142-1f1a33295efe',
#  '808b36a1-a597-47c9-aa11-84794c2c5e83',
#  '997d212b-8806-4363-8e23-f114766ae98d',
#  '4800dbe2-fb9b-4fd8-8b27-bb1d2a55acdf',
#  '15fa38f7-3dd8-4b61-8e6c-ac18b21e2f8e',
#  'e82aa08b-2976-4a04-b936-b7e355a35744',
#  'd66bdcd4-7ffc-42af-ae20-925453500d75',
#  'c4bf7bf7-bfc6-489c-ae9b-bbab2b5af15a',
#  '3387c901-9ed5-4e9b-b962-b35255e6765a',
#  '8bec5343-2296-4f3b-a6ab-f48969690f52',
#  'f0ddefb7-81f7-4ed9-8f77-d5928c5afdf7',
#  'ebf9a9df-970e-44b6-87d5-fc4c8717185d',
#  '6c4e8a87-52ae-45ca-acc0-e1a5076b0c10',
#  '9c173278-94a5-4d0a-81ba-8867b775a1e4',
#  '8dafc9b5-8d2d-4772-986a-30deb0c99485',
#  'cadac55c-e266-4c82-b299-11cc012ff888',
#  'bfe9daee-139f-4127-97a6-a02c28fc42e8',
#  '581104ad-84be-44f3-a241-c430f5fe0554',
#  'f759269d-5e61-47fe-b1a9-c1c8984af0d6',
#  '440b5804-58fd-4b04-93c2-bc44c3754b86',
#  '15477602-3c70-4b6c-8935-d5f630f9f6c4',
#  '7084de57-5d45-4a05-ada1-28df79d92748',
#  '3605ed83-86a3-494a-b087-3374f5f9f553',
#  '0872b8f0-42a0-4ea3-a93a-d884aafd8aac',
#  '328becfd-24dd-43f7-874c-c0f8c4ae0742',
#  '961919a5-612d-4383-82f8-71caa7ba6c2a',
#  '6137f11b-c51b-453b-97dc-e4f8455147dc',
#  '7ff6e5a3-0685-4a67-bb4f-c5880ca3239e',
#  'dffff067-22cb-46fb-b033-d0fe1dd57970',
#  'd1f1082a-767c-4257-9eb5-f5fe1a942052',
#  '6567971d-5ce7-4e78-83c4-c04baec7a8fa',
#  '877adec9-a712-4c0d-a570-da14c133bb4e',
#  '360f82af-3bed-44f8-9b61-91b17d322ba7',
#  'b66880ed-b0ff-4d86-8e22-8f8e56fb2b57',
#  '9147923d-12c9-405e-b804-be0348d375ee',
#  '999d201a-3c81-457c-bd4e-2331c7219959',
#  'e7c6b014-091c-4f2b-8003-073995ebda6c',
#  '0b379af3-a58f-4fbd-ac18-f2cea701600d',
#  'be2d6138-8beb-4c4b-b349-b9149daa3c75',
#  'd4120b2d-8a44-4514-833f-7396469808c6',
#  '216347a7-4b48-4f5a-8a49-c43c525f2619',
#  '8b030bb7-d88a-4c39-b3bc-9269ba991de8',
#  'c03c08c6-6b3d-404e-a2b0-632aa1e442e3',
#  '2b8c0008-e196-40f1-9fe0-3bbf10498fbf',
#  '749ca230-7fe3-4064-bb8e-b3c93502b32b',
#  '24a86a06-31f3-40a6-b128-6fe60538f508',
#  '49aa9ca9-7fae-4c18-b5b7-db3ef00fe152',
#  'd77aed32-004f-4978-84c9-2c96a37a1b64',
#  '9cd81be9-1f03-459c-8002-2c68d1045086',
#  'eba7dd47-0a03-46c2-9e25-63cef195677d',
#  '63edb883-c150-4b11-8d57-d51ee892b991',
#  'a27869ef-9da8-4750-a9d1-db60b4fabee0',
#  '4a4d8224-4a61-4cf9-90d3-7652a979ab16',
#  'a84edf43-734f-4844-9573-f20b4ac1425a',
#  '78c3a49d-9409-469f-a733-732016a6668c',
#  '57cd4d98-7002-4ca2-81e9-79c125499095',
#  'cec3ed7a-3060-4893-8bde-47c85cebee09',
#  '6d47a676-8afe-42be-9141-d71a610dfe50',
#  'a6db5dfc-054c-4a34-9735-cc03f1aab8aa',
#  '803237b9-a387-44c2-a332-6ff164672682',
#  'd9e6c740-994e-466f-8e4a-47cfdc85575d',
#  '9080c6a9-5a39-4217-ba22-c6ca718c19e7',
#  '05caf251-d716-4905-8578-09e55ea2a887',
#  '609b4330-243a-4289-bb8c-7f3352d962e9',
#  '171a296b-1050-47cf-8a6b-7e5bf8196f1f',
#  '15501f04-d508-4fa8-8582-389a09a9f094',
#  '0030535c-51b5-42d7-8a74-12f5add3b1ed',
#  '3c14364d-32ea-4c27-8df0-a275971115a2',
#  'd534fbb9-bd67-43b0-8517-585292fd2642',
#  '421818fe-b1a4-4efc-aaea-bbf73a7dd894',
#  '5a70c725-b656-4bfe-963d-93c93eedc462',
#  '52ede806-32ce-4747-b36e-c69b8d4dc215',
#  'a6a7a06d-5360-4c64-b180-d13184e568b2',
#  'f55d0966-fe50-494d-abc4-721c2ca2cdd8',
#  'bdacf908-e5b8-4d60-ab0e-4f6691312118',
#  '34d9efc8-aac6-419b-ab20-34071252c53a',
#  '759a1b7f-4ea4-4f2b-8294-73e37b11c876',
#  '02e97a7d-5f13-498c-81e4-04c21b474ac6',
#  'b8a8e092-975b-4cad-98f0-0b1223bb17f4',
#  'f94e15b0-4fb5-456b-bff9-b37c53a49de9',
#  'e7e913c2-06ce-4760-b379-92a3314ae648']

# %%
# Helper function to join the retrieved chunks

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
# Step 1: Initialize the Chroma DB Connection

from langchain_chroma import Chroma
from langchain_core.runnables import RunnablePassthrough

# Initialize the database connection
# If database exist, it will connect with the collection_name and persist_directory
# Otherwise a new collection will be created
db = Chroma(collection_name="vector_database", 
            embedding_function=hf, 
            persist_directory="./chroma_db_")

# We can check the already existing values
#print(len(db.get()["ids"]))


# Step 2: Create a Retriever Object 

retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 3})

# Step 3: Initialize a Chat Prompt Template

from langchain_core.prompts import ChatPromptTemplate

PROMPT_TEMPLATE = """
Answer the question based only on the following context:
{context}
Answer the question based on the above context: {question}.
Provide a detailed answer.
Don’t justify your answers.
Don’t give information not mentioned in the CONTEXT INFORMATION.
Do not say "according to the context" or "mentioned in the context" or similar.
"""

prompt_template = ChatPromptTemplate(
    messages=[
        PROMPT_TEMPLATE
    ]
)

# step 4: Define chatmodel

f = open('keys/google-api.txt')

GOOGLE_API_KEY = f.read()

from langchain_google_genai import ChatGoogleGenerativeAI
# Pass the standard parameters during initialization
google_chat_model = ChatGoogleGenerativeAI(api_key=GOOGLE_API_KEY, 
                                           model="gemini-2.5-flash", 
                                           temperature=1)

from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# build generator chain now

generator_chain = prompt_template|google_chat_model|parser

rag_chain = { "context" : retriever | format_docs,
              "question" : RunnablePassthrough()} | generator_chain



rag_chain.invoke("How does Alzheimer’s disease affect behavior?")
# Out:
# "Alzheimer's disease affects behavior in several ways. As the disease advances, individuals can experience mood swings, loss of motivation, self-neglect, and general behavioral issues. They often withdraw from family and society. Behavioral and neuropsychiatric changes become more prevalent, including wandering, irritability, and emotional liability, which can lead to crying, outbursts of unpremeditated aggression, or resistance to caregiving. Sundowning can also appear. Approximately 30% of people with Alzheimer's disease develop illusionary misidentifications and other delusional symptoms. Subjects also lose insight into their disease process and limitations, a condition known as anosognosia."
